# %% [markdown]
# ### Q.2) Create a DataFrame using static student data with columns:
# #### name, gender, dwdm, ecommerce, strategical management.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    'name': ['Aayush', 'Swornim', 'Nilima', 'Aarjan', 'Nirajan'],
    'gender': ['Male', 'Male', 'Female', 'Male', 'Male'],
    'dwdm': [88, 92, 95, 85, 84],
    'ecommerce': [80, 88, 94, 82, 85],
    'strategical_management': [90, 90, 92, 86, 88]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       name  gender  dwdm  ecommerce  strategical_management
# 0   Aayush    Male    65         70                      60
# 1  Swornim    Male    92         88                      90
# 2   Nilima  Female    95         94                      92
# 3   Aarjan    Male    85         82                      86
# 4  Nirajan    Male    84         85                      88
